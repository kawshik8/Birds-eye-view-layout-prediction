# %%
# !python3 visualize.py
# Out:
# bce det_encoder
# ['obj_road_map_var_bce', '.DS_Store', 'obj_road_map_det_bce', 'road_map_det_bce', 'road_map_det_mse', 'road_map_var_mse', 'road_map_var_bce', '.ipynb_checkpoints']
# ['obj_road_map_det_bce']
# Traceback (most recent call last):
#   File "visualize.py", line 95, in <module>
#     boxes = batch_output["boxes"].detach().numpy()
# KeyError: 'boxes'

# %%
# !pwd
# Out:
# /Users/kawshik/NYU/Sem 2/Deep Learning/project/github/DL-project/notebooks

# %%
model = torch.load("../../../sub_models1/results/road_map_var_mse/finetune_custom_sup_best.ckpt", map_location=torch.device('cpu'))
print(model)
# Out:
# OrderedDict([('init_layers.0.weight', tensor([[[[-8.8722e-03, -1.0827e-02,  4.9305e-03,  ..., -6.0248e-02,
#            -1.0331e-02,  2.6266e-02],
#           [ 4.0802e-02,  6.9409e-04, -2.2447e-02,  ..., -7.7725e-03,
#            -3.3655e-02,  4.3134e-02],
#           [ 1.3930e-02, -1.8240e-02, -1.8156e-02,  ..., -2.3862e-02,
#            -1.2850e-03,  1.1593e-02],
#           ...,
#           [ 4.9139e-02, -3.2217e-02,  4.4547e-02,  ...,  3.1358e-02,
#             2.4635e-02,  6.6842e-04],
#           [-1.3837e-02,  8.4313e-03,  4.6593e-03,  ..., -1.6748e-02,
#            -1.5502e-02,  1.4355e-02],
#           [ 2.9014e-02,  1.2180e-02, -1.9853e-03,  ...,  9.4807e-04,
#             1.4352e-03,  2.7396e-03]],
#
#          [[-1.0645e-02,  1.9230e-02,  2.8067e-02,  ...,  3.0626e-02,
#             2.9641e-02,  5.2030e-02],
#           [-2.8206e-03,  1.9230e-02, -1.7209e-02,  ...,  1.8749e-02,
#             2.3477e-03,  1.4860e-02],
# ...

# %%
print(model.layers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-7a2f20ea064f> in <module>
# ----> 1 print(model.layers)
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'layers'
